# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import json

# %% [markdown]
# # Datos - Códigos Departamentos

# %%
df_departamentos_codigos = pd.read_csv('../../Data/Departamentos_Codigos.csv')

# %%
df_departamentos_codigos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Codigo                               33 non-null     int64
#  1   Departamento_DANE                    33 non-null     object
#  2   Departamento_DIVIPOLA                33 non-null     object
#  3   Departamento_REPS                    33 non-null     object
#  4   Departamento_IPS_Complejidad         33 non-null     object
#  5   Departamento_IPS_Atencion_Capacidad  33 non-null     object
#  6   Departamento_Capacidad_Instalada     33 non-null     object
#  7   Departamento_Radiografia             33 non-null     object
#  8   Departamento_Caracterizacion         33 non-null     object
#  9   Departamento                         33 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 2.7+ KB

# %%
df_departamentos_codigos.head()
# Out:
#    Codigo Departamento_DANE Departamento_DIVIPOLA Departamento_REPS  \
# 0       5         Antioquia             ANTIOQUIA         Antioquia
# 1       8         Atlántico             ATLÁNTICO        AtlÃ¡ntico
# 2      11      Bogotá, D.C.          BOGOTÁ, D.C.       BogotÃ¡ D.C
# 3      13           Bolívar               BOLÍVAR          BolÃ­var
# 4      15            Boyacá                BOYACÁ           BoyacÃ¡
#
#   Departamento_IPS_Complejidad Departamento_IPS_Atencion_Capacidad  \
# 0                    Antioquia                           Antioquia
# 1                   AtlÃ¡ntico                          AtlÃ¡ntico
# 2                  BogotÃ¡ D.C                         BogotÃ¡ D.C
# 3                     BolÃ­var                            BolÃ­var
# 4                      BoyacÃ¡                             BoyacÃ¡
#
#   Departamento_Capacidad_Instalada Departamento_Radiografia  \
# 0                        Antioquia                Antioquia
# 1                       AtlÃ¡ntico                Atlántico
# 2                    BogotÃ¡, D.C.               Bogotá D.C
# 3                         BolÃ­var                  Bolívar
# 4                          BoyacÃ¡                   Boyacá
#
#   Departamento_Caracterizacion Departamento
# 0                    Antioquia    Antioquia
# 1                    Atlántico    Atlántico
# 2                   Bogotá D.C   Bogotá D.C
# 3                      Bolívar      Bolívar
# 4                       Boyacá       Boyacá

# %% [markdown]
# # Datos - Códigos Municipios

# %%
df_municipios_codigos = pd.read_csv('../../Data/Departamentos_Municipios_Codigos.csv')

# %%
df_municipios_codigos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121 entries, 0 to 1120
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Codigo_Departamento               1121 non-null   int64
#  1   Departamento                      1121 non-null   object
#  2   Codigo_Municipio                  1121 non-null   int64
#  3   Municipio                         1121 non-null   object
#  4   Municipio_DIVIPOLA                1121 non-null   object
#  5   Municipio_Poblacion               1121 non-null   object
#  6   Municipio_REPS                    1121 non-null   object
#  7   Municipio_IPS_Complejidad         1121 non-null   object
#  8   Municipio_IPS_Atencion_Capacidad  1121 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 78.9+ KB

# %%
df_municipios_codigos.head()
# Out:
#    Codigo_Departamento Departamento  Codigo_Municipio   Municipio  \
# 0                    5    ANTIOQUIA              5001    Medellín
# 1                    5    ANTIOQUIA              5002   Abejorral
# 2                    5    ANTIOQUIA              5004    Abriaquí
# 3                    5    ANTIOQUIA              5021  Alejandría
# 4                    5    ANTIOQUIA              5030       Amagá
#
#   Municipio_DIVIPOLA Municipio_Poblacion Municipio_REPS  \
# 0           MEDELLÍN            Medellín      MEDELLÃN
# 1          ABEJORRAL           Abejorral      ABEJORRAL
# 2           ABRIAQUÍ            Abriaquí      ABRIAQUÃ
# 3         ALEJANDRÍA          Alejandría    ALEJANDRÃA
# 4              AMAGÁ               Amagá         AMAGÃ
#
#   Municipio_IPS_Complejidad Municipio_IPS_Atencion_Capacidad
# 0                 MEDELLÃN                        MEDELLÃN
# 1                 ABEJORRAL                        ABEJORRAL
# 2                 ABRIAQUÃ                        ABRIAQUÃ
# 3               ALEJANDRÃA                      ALEJANDRÃA
# 4                    AMAGÃ                           AMAGÃ

# %% [markdown]
# # Datos - REPS

# %%
df_reps = pd.read_csv('../../Data/REPS.csv')
# Out:
# C:\Users\SGM\AppData\Local\Temp\ipykernel_19840\3122532733.py:1: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_reps = pd.read_csv('../../Data/REPS.csv')

# %%
df_reps['codigo_prestador'] = df_reps['CodigoPrestador']
df_reps['codigo_habilitacion_sede'] = df_reps['CodigoHabilitacionSede']
df_reps.iloc[56503]['CodigoPrestador'], df_reps.iloc[56503]['CodigoHabilitacionSede'], df_reps.iloc[74472]['CodigoPrestador'], df_reps.iloc[74472]['CodigoHabilitacionSede']

df_reps.at[56503, 'codigo_prestador'] = df_reps.iloc[56503]['CodigoPrestador'].replace(" ", "")
df_reps.at[56503, 'codigo_habilitacion_sede'] = df_reps.iloc[56503]['CodigoHabilitacionSede'].replace(" ", "")
df_reps.at[74472, 'codigo_prestador'] = df_reps.iloc[74472]['CodigoPrestador'].replace(" ", "")
df_reps.at[74472, 'codigo_habilitacion_sede'] = df_reps.iloc[74472]['CodigoHabilitacionSede'].replace(" ", "")

df_reps['codigo_prestador'] = df_reps['codigo_prestador'].astype(np.int64)
df_reps['codigo_habilitacion_sede'] = df_reps['codigo_habilitacion_sede'].astype(np.int64)

# %%
departamentos = [
    'Amazonas', 'Antioquia', 'Arauca', 'Atlántico',
    'Bogotá D.C', 'Bolívar', 'Boyacá', 'Caldas',
    'Caquetá', 'Casanare', 'Cauca', 'Cesar', 
    'Chocó', 'Córdoba', 'Cundinamarca', 'Guainía', 
    'Guaviare', 'Huila', 'La Guajira', 'Magdalena',
    'Meta', 'Nariño', 'Norte de Santander', 'Putumayo',
    'Quindío', 'Risaralda', 'San Andrés y Providencia', 'Santander',
    'Sucre', 'Tolima', 'Valle del cauca', 'Vaupés', 
    'Vichada'
    ]

distritos_especiales = [
    'Barranquilla',
    'Buenaventura',
    'Cartagena',
    'Santa Marta'
]

distritos_especiales_departamentos = {
    'Barranquilla': 'Atlántico',
    'Buenaventura': 'Valle del cauca',
    'Cartagena': 'Bolívar',
    'Santa Marta': 'Magdalena',
    'Cali': 'Valle del cauca'
}

# %%
df_reps['Departamento'] = df_reps['DepartamentoSedeDesc'].replace(distritos_especiales_departamentos)
df_reps = df_reps[df_reps['ClasePrestadorDesc'] == 'Instituciones Prestadoras de Servicios de Salud - IPS']

# %%
columnas = [
    'DepartamentoSedeDesc',
    'MunicipioPrestadorDesc',
    'MunicipioSede',
    'MunicipioSedeDesc',
    'codigo_prestador',
    'codigo_habilitacion_sede',
    'NaturalezaJuridica',
    # 'ClasePrestadorDesc'
]

# %%
df_reps = df_reps[columnas]

# %%
df_reps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19726 entries, 0 to 76393
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DepartamentoSedeDesc      19726 non-null  object
#  1   MunicipioPrestadorDesc    19726 non-null  object
#  2   MunicipioSede             19726 non-null  int64
#  3   MunicipioSedeDesc         19726 non-null  object
#  4   codigo_prestador          19726 non-null  int64
#  5   codigo_habilitacion_sede  19726 non-null  int64
#  6   NaturalezaJuridica        19726 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.2+ MB

# %%
df_reps.head()
# Out:
#   DepartamentoSedeDesc MunicipioPrestadorDesc  MunicipioSede  \
# 0             Amazonas                LETICIA          91263
# 1             Amazonas                LETICIA          91405
# 2             Amazonas                LETICIA          91407
# 3             Amazonas                LETICIA          91430
# 5             Amazonas                LETICIA          91001
#
#   MunicipioSedeDesc  codigo_prestador  codigo_habilitacion_sede  \
# 0        EL ENCANTO        9100100019              912630001911
# 1       LA CHORRERA        9100100019              914050001914
# 2        LA PEDRERA        9100100019              914070001915
# 3       LA VICTORIA        9100100019              914300001916
# 5           LETICIA        9100100019              910010001901
#
#   NaturalezaJuridica
# 0            Pública
# 1            Pública
# 2            Pública
# 3            Pública
# 5            Pública

# %% [markdown]
# # Datos - IPS Complejidad

# %%
df_ips = pd.read_csv("../../Data/IPS_Complejidad.csv")

# %%
departamentos = [
    'Amazonas', 'Antioquia', 'Arauca', 'Atlántico',
    'Bogotá D.C', 'Bolívar', 'Boyacá', 'Caldas',
    'Caquetá', 'Casanare', 'Cauca', 'Cesar', 
    'Chocó', 'Córdoba', 'Cundinamarca', 'Guainía', 
    'Guaviare', 'Huila', 'La Guajira', 'Magdalena',
    'Meta', 'Nariño', 'Norte de Santander', 'Putumayo',
    'Quindío', 'Risaralda', 'San Andrés y Providencia', 'Santander',
    'Sucre', 'Tolima', 'Valle del cauca', 'Vaupés', 
    'Vichada'
    ]

distritos_especiales = [
    'Barranquilla',
    'Buenaventura',
    'Cartagena',
    'Santa Marta'
]

distritos_especiales_departamentos = {
    'Barranquilla': 'Atlántico',
    'Buenaventura': 'Valle del cauca',
    'Cartagena': 'Bolívar',
    'Santa Marta': 'Magdalena'
}

# %%
columnas = [
    'depa_nombre',
    'muni_nombre',
    'codigo_habilitacion',
    # 'razon_social',
    'nivel',
    # 'habilitado',
    # 'naju_codigo',
    'naju_nombre',
    'clase_persona'
]

# %%
df_ips = df_ips[columnas]
df_ips['Departamento'] = df_ips['depa_nombre'].replace(distritos_especiales_departamentos)

# %%
df_ips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11466 entries, 0 to 11465
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   depa_nombre          11466 non-null  object
#  1   muni_nombre          11466 non-null  object
#  2   codigo_habilitacion  11466 non-null  int64
#  3   nivel                1002 non-null   float64
#  4   naju_nombre          11466 non-null  object
#  5   clase_persona        11466 non-null  object
#  6   Departamento         11466 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 627.2+ KB

# %%
df_ips.head()
# Out:
#   depa_nombre muni_nombre  codigo_habilitacion  nivel naju_nombre  \
# 0    Amazonas     LETICIA           9100100019    2.0     Pública
# 1    Amazonas     LETICIA           9100100185    NaN     Privada
# 2    Amazonas     LETICIA           9100100069    NaN     Privada
# 3    Amazonas     LETICIA           9100100158    NaN     Privada
# 4    Amazonas     LETICIA           9100100144    NaN     Privada
#
#   clase_persona Departamento
# 0      JURIDICO     Amazonas
# 1      JURIDICO     Amazonas
# 2      JURIDICO     Amazonas
# 3      JURIDICO     Amazonas
# 4      JURIDICO     Amazonas

# %% [markdown]
# # IPS Públicas

# %%
df_ips_publica = df_ips[df_ips['naju_nombre'] == 'Pública']

# %%
df_ips_publica
# Out:
#            depa_nombre     muni_nombre  codigo_habilitacion  nivel  \
# 0             Amazonas         LETICIA           9100100019    2.0
# 6             Amazonas         LETICIA           9100100168    1.0
# 14           Antioquia       ABEJORRAL            500204360    1.0
# 15           Antioquia      ALEJANDRÍA            502105098    1.0
# 16           Antioquia           AMAGÁ            503004374    1.0
# ...                ...             ...                  ...    ...
# 11447  Valle del cauca           YUMBO           7689204073    1.0
# 11453  Valle del cauca          ZARZAL           7689504656    2.0
# 11455           Vaupés            MITÚ           9700100013    1.0
# 11456           Vaupés            MITÚ           9700100001    2.0
# 11463          Vichada  PUERTO CARREÑO           9900100006    2.0
#
#       naju_nombre clase_persona     Departamento
# 0         Pública      JURIDICO         Amazonas
# 6         Pública      JURIDICO         Amazonas
# 14        Pública      JURIDICO        Antioquia
# 15        Pública      JURIDICO        Antioquia
# 16        Pública      JURIDICO        Antioquia
# ...           ...           ...              ...
# 11447     Pública      JURIDICO  Valle del cauca
# 11453     Pública      JURIDICO  Valle del cauca
# 11455     Pública      JURIDICO           Vaupés
# 11456     Pública      JURIDICO           Vaupés
# 11463     Pública      JURIDICO          Vichada
#
# [1002 rows x 7 columns]

# %%
df_reps_publica = df_reps[df_reps['NaturalezaJuridica'] == 'Pública']

# %%
df_reps_publica
# Out:
#       DepartamentoSedeDesc MunicipioPrestadorDesc  MunicipioSede  \
# 0                 Amazonas                LETICIA          91263
# 1                 Amazonas                LETICIA          91405
# 2                 Amazonas                LETICIA          91407
# 3                 Amazonas                LETICIA          91430
# 5                 Amazonas                LETICIA          91001
# ...                    ...                    ...            ...
# 76359               Vaupés                   MITÚ          97889
# 76360              Vichada         PUERTO CARREÑO          99773
# 76365              Vichada         PUERTO CARREÑO          99524
# 76370              Vichada         PUERTO CARREÑO          99001
# 76392              Vichada         PUERTO CARREÑO          99624
#
#       MunicipioSedeDesc  codigo_prestador  codigo_habilitacion_sede  \
# 0            EL ENCANTO        9100100019              912630001911
# 1           LA CHORRERA        9100100019              914050001914
# 2            LA PEDRERA        9100100019              914070001915
# 3           LA VICTORIA        9100100019              914300001916
# 5               LETICIA        9100100019              910010001901
# ...                 ...               ...                       ...
# 76359          YAVARATÉ        9700100001              978890000166
# 76360          CUMARIBO        9900100006              997730000607
# 76365      LA PRIMAVERA        9900100006              995240000608
# 76370    PUERTO CARREÑO        9900100006              990010000601
# 76392     SANTA ROSALÍA        9900100006              996240000609
#
#       NaturalezaJuridica
# 0                Pública
# 1                Pública
# 2                Pública
# 3                Pública
# 5                Pública
# ...                  ...
# 76359            Pública
# 76360            Pública
# 76365            Pública
# 76370            Pública
# 76392            Pública
#
# [3621 rows x 7 columns]

# %%
set1 = set(df_ips_publica['codigo_habilitacion'].unique())
len(set1)
# Out:
# 1002

# %%
set2 = set(df_reps_publica['codigo_prestador'].unique())
len(set2)
# Out:
# 999

# %%
len(set.intersection(set1, set2))
# Out:
# 996

# %% [markdown]
# # Merge

# %%
df_reps_merge = pd.merge(df_reps_publica, df_ips_publica, how='inner', left_on='codigo_prestador', right_on='codigo_habilitacion')

# %%
df_reps_merge
# Out:
#      DepartamentoSedeDesc MunicipioPrestadorDesc  MunicipioSede  \
# 0                Amazonas                LETICIA          91263
# 1                Amazonas                LETICIA          91405
# 2                Amazonas                LETICIA          91407
# 3                Amazonas                LETICIA          91430
# 4                Amazonas                LETICIA          91001
# ...                   ...                    ...            ...
# 3608               Vaupés                   MITÚ          97889
# 3609              Vichada         PUERTO CARREÑO          99773
# 3610              Vichada         PUERTO CARREÑO          99524
# 3611              Vichada         PUERTO CARREÑO          99001
# 3612              Vichada         PUERTO CARREÑO          99624
#
#      MunicipioSedeDesc  codigo_prestador  codigo_habilitacion_sede  \
# 0           EL ENCANTO        9100100019              912630001911
# 1          LA CHORRERA        9100100019              914050001914
# 2           LA PEDRERA        9100100019              914070001915
# 3          LA VICTORIA        9100100019              914300001916
# 4              LETICIA        9100100019              910010001901
# ...                ...               ...                       ...
# 3608          YAVARATÉ        9700100001              978890000166
# 3609          CUMARIBO        9900100006              997730000607
# 3610      LA PRIMAVERA        9900100006              995240000608
# 3611    PUERTO CARREÑO        9900100006              990010000601
# 3612     SANTA ROSALÍA        9900100006              996240000609
#
#      NaturalezaJuridica depa_nombre     muni_nombre  codigo_habilitacion  \
# 0               Pública    Amazonas         LETICIA           9100100019
# 1               Pública    Amazonas         LETICIA           9100100019
# 2               Pública    Amazonas         LETICIA           9100100019
# 3               Pública    Amazonas         LETICIA           9100100019
# 4               Pública    Amazonas         LETICIA           9100100019
# ...                 ...         ...             ...                  ...
# 3608            Pública      Vaupés            MITÚ           9700100001
# 3609            Pública     Vichada  PUERTO CARREÑO           9900100006
# 3610            Pública     Vichada  PUERTO CARREÑO           9900100006
# 3611            Pública     Vichada  PUERTO CARREÑO           9900100006
# 3612            Pública     Vichada  PUERTO CARREÑO           9900100006
#
#       nivel naju_nombre clase_persona Departamento
# 0       2.0     Pública      JURIDICO     Amazonas
# 1       2.0     Pública      JURIDICO     Amazonas
# 2       2.0     Pública      JURIDICO     Amazonas
# 3       2.0     Pública      JURIDICO     Amazonas
# 4       2.0     Pública      JURIDICO     Amazonas
# ...     ...         ...           ...          ...
# 3608    2.0     Pública      JURIDICO       Vaupés
# 3609    2.0     Pública      JURIDICO      Vichada
# 3610    2.0     Pública      JURIDICO      Vichada
# 3611    2.0     Pública      JURIDICO      Vichada
# 3612    2.0     Pública      JURIDICO      Vichada
#
# [3613 rows x 14 columns]

# %%
# Nulos sin nivel
df_reps_merge[df_reps_merge.isna().any(axis=1)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 1256 to 3252
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DepartamentoSedeDesc      11 non-null     object
#  1   MunicipioPrestadorDesc    11 non-null     object
#  2   MunicipioSede             11 non-null     int64
#  3   MunicipioSedeDesc         11 non-null     object
#  4   codigo_prestador          11 non-null     int64
#  5   codigo_habilitacion_sede  11 non-null     int64
#  6   NaturalezaJuridica        11 non-null     object
#  7   depa_nombre               11 non-null     object
#  8   muni_nombre               11 non-null     object
#  9   codigo_habilitacion       11 non-null     int64
#  10  nivel                     0 non-null      float64
#  11  naju_nombre               11 non-null     object
#  12  clase_persona             11 non-null     object
#  13  Departamento              11 non-null     object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 1.3+ KB

# %%
df_reps_merge.dropna(inplace=True)
df_reps_merge['nivel'] = df_reps_merge['nivel'].astype('int64')

# %%
df_reps_merge
# Out:
#      DepartamentoSedeDesc MunicipioPrestadorDesc  MunicipioSede  \
# 0                Amazonas                LETICIA          91263
# 1                Amazonas                LETICIA          91405
# 2                Amazonas                LETICIA          91407
# 3                Amazonas                LETICIA          91430
# 4                Amazonas                LETICIA          91001
# ...                   ...                    ...            ...
# 3608               Vaupés                   MITÚ          97889
# 3609              Vichada         PUERTO CARREÑO          99773
# 3610              Vichada         PUERTO CARREÑO          99524
# 3611              Vichada         PUERTO CARREÑO          99001
# 3612              Vichada         PUERTO CARREÑO          99624
#
#      MunicipioSedeDesc  codigo_prestador  codigo_habilitacion_sede  \
# 0           EL ENCANTO        9100100019              912630001911
# 1          LA CHORRERA        9100100019              914050001914
# 2           LA PEDRERA        9100100019              914070001915
# 3          LA VICTORIA        9100100019              914300001916
# 4              LETICIA        9100100019              910010001901
# ...                ...               ...                       ...
# 3608          YAVARATÉ        9700100001              978890000166
# 3609          CUMARIBO        9900100006              997730000607
# 3610      LA PRIMAVERA        9900100006              995240000608
# 3611    PUERTO CARREÑO        9900100006              990010000601
# 3612     SANTA ROSALÍA        9900100006              996240000609
#
#      NaturalezaJuridica depa_nombre     muni_nombre  codigo_habilitacion  \
# 0               Pública    Amazonas         LETICIA           9100100019
# 1               Pública    Amazonas         LETICIA           9100100019
# 2               Pública    Amazonas         LETICIA           9100100019
# 3               Pública    Amazonas         LETICIA           9100100019
# 4               Pública    Amazonas         LETICIA           9100100019
# ...                 ...         ...             ...                  ...
# 3608            Pública      Vaupés            MITÚ           9700100001
# 3609            Pública     Vichada  PUERTO CARREÑO           9900100006
# 3610            Pública     Vichada  PUERTO CARREÑO           9900100006
# 3611            Pública     Vichada  PUERTO CARREÑO           9900100006
# 3612            Pública     Vichada  PUERTO CARREÑO           9900100006
#
#       nivel naju_nombre clase_persona Departamento
# 0         2     Pública      JURIDICO     Amazonas
# 1         2     Pública      JURIDICO     Amazonas
# 2         2     Pública      JURIDICO     Amazonas
# 3         2     Pública      JURIDICO     Amazonas
# 4         2     Pública      JURIDICO     Amazonas
# ...     ...         ...           ...          ...
# 3608      2     Pública      JURIDICO       Vaupés
# 3609      2     Pública      JURIDICO      Vichada
# 3610      2     Pública      JURIDICO      Vichada
# 3611      2     Pública      JURIDICO      Vichada
# 3612      2     Pública      JURIDICO      Vichada
#
# [3602 rows x 14 columns]

# %%
df_reps_merge['nivel'].unique()
# Out:
# array([2, 1, 3], dtype=int64)
