# %% [markdown]
# # Librerías

# %%
import pandas as pd

# %% [markdown]
# # Departamentos Codigos

# %%
df_departamentos_codigos = pd.read_csv('../Data/Departamentos_Codigos.csv')

# %%
df_departamentos_codigos
# Out:
#     Codigo           Departamento_DANE  \
# 0        5                   Antioquia
# 1        8                   Atlántico
# 2       11                Bogotá, D.C.
# 3       13                     Bolívar
# 4       15                      Boyacá
# 5       17                      Caldas
# 6       18                     Caquetá
# 7       19                       Cauca
# 8       20                       Cesar
# 9       23                     Córdoba
# 10      25                Cundinamarca
# 11      27                       Chocó
# 12      41                       Huila
# 13      44                  La Guajira
# 14      47                   Magdalena
# 15      50                        Meta
# 16      52                      Nariño
# 17      54          Norte de Santander
# 18      63                     Quindio
# 19      66                   Risaralda
# 20      68                   Santander
# 21      70                       Sucre
# 22      73                      Tolima
# ...

# %% [markdown]
# # Capacidad Instalada

# %%
df_capacidad_instalada = pd.read_csv('./Data/Capacidad_Instalada_Transformed.csv')

# %%
df_capacidad_instalada = pd.merge(df_capacidad_instalada, df_departamentos_codigos[['Codigo', 'Departamento_Capacidad_Instalada']], how='left', left_on='Departamento', right_on='Departamento_Capacidad_Instalada')
df_capacidad_instalada.drop('Departamento_Capacidad_Instalada', axis=1, inplace=True)

# %%
df_capacidad_instalada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 10 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Anio                                      692 non-null    int64
#  1   Departamento                              692 non-null    object
#  2   Camas de hospitalización                  692 non-null    int64
#  3   Camas de observación                      692 non-null    int64
#  4   Consultorios de consulta externa          692 non-null    int64
#  5   Consultorios en el servicio de urgencias  692 non-null    int64
#  6   Mesas de partos                           692 non-null    int64
#  7   Número de unidades de odontología         692 non-null    int64
#  8   Salas de quirófanos                       692 non-null    int64
#  9   Codigo                                    671 non-null    float64
# ...

# %%
df_capacidad_instalada
# Out:
#      Anio                                       Departamento  \
# 0    2002                                           Amazonas
# 1    2002                                          Antioquia
# 2    2002                                             Arauca
# 3    2002  Archipiélago de San Andrés, Providencia y Sant...
# 4    2002                                          Atlántico
# ..    ...                                                ...
# 687  2022                                              Sucre
# 688  2022                                             Tolima
# 689  2022                                    Valle del Cauca
# 690  2022                                             Vaupés
# 691  2022                                            Vichada
#
#      Camas de hospitalización  Camas de observación  \
# 0                         115                     8
# 1                        2816                   556
# 2                         233                    39
# ...

# %%
df_capacidad_instalada[df_capacidad_instalada.isna().any(axis=1)]
# Out:
#      Anio Departamento  Camas de hospitalización  Camas de observación  \
# 22   2002     Nacional                     25224                  4742
# 56   2003     Nacional                     25185                  5229
# 90   2004     Nacional                     24853                  5508
# 124  2005     Nacional                     24729                  5897
# 158  2006     Nacional                     24945                  6360
# 191  2007     Nacional                     25121                  6010
# 224  2008     Nacional                     24882                  6270
# 256  2009     Nacional                     25087                  6664
# 288  2010     Nacional                     25050                  6988
# 321  2011     Nacional                     26601                  7510
# 354  2012     Nacional                     26025                  7456
# 387  2013     Nacional                     26013                  7733
# ...

# %% [markdown]
# # Poblacion - 1993 - 2004

# %%
df_1993_2004 = pd.read_csv('../Data/Poblacion_Departamento_1993_2004.csv')

# %%
df_1993_2004 = df_1993_2004[df_1993_2004['ÁREA GEOGRÁFICA'] == 'Total']

# %%
df_1993_2004
# Out:
#       DP      DPNOM   AÑO ÁREA GEOGRÁFICA  Población
# 2      5  Antioquia  1993           Total    4607874
# 5      5  Antioquia  1994           Total    4679652
# 8      5  Antioquia  1995           Total    4753428
# 11     5  Antioquia  1996           Total    4828617
# 14     5  Antioquia  1997           Total    4904267
# ...   ..        ...   ...             ...        ...
# 1175  99    Vichada  2000           Total      66332
# 1178  99    Vichada  2001           Total      68523
# 1181  99    Vichada  2002           Total      70763
# 1184  99    Vichada  2003           Total      73034
# 1187  99    Vichada  2004           Total      75328
#
# [396 rows x 5 columns]

# %% [markdown]
# # Poblacion - 2005 - 2019

# %%
df_2005_2019 = pd.read_csv('../Data/Poblacion_Departamento_2005_2019.csv')

# %%
df_2005_2019 = df_2005_2019[df_2005_2019['ÁREA GEOGRÁFICA'] == 'Total']

# %%
df_2005_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 495 entries, 2 to 1484
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DP               495 non-null    int64
#  1   DPNOM            495 non-null    object
#  2   AÑO              495 non-null    int64
#  3   ÁREA GEOGRÁFICA  495 non-null    object
#  4   Población        495 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 23.2+ KB

# %%
df_2005_2019
# Out:
#       DP      DPNOM   AÑO ÁREA GEOGRÁFICA  Población
# 2      5  Antioquia  2005           Total    5460843
# 5      5  Antioquia  2006           Total    5528121
# 8      5  Antioquia  2007           Total    5595180
# 11     5  Antioquia  2008           Total    5662099
# 14     5  Antioquia  2009           Total    5730377
# ...   ..        ...   ...             ...        ...
# 1472  91   Amazonas  2019           Total      77753
# 1475  94    Guainía  2019           Total      49473
# 1478  95   Guaviare  2019           Total      84716
# 1481  97     Vaupés  2019           Total      42721
# 1484  99    Vichada  2019           Total     110599
#
# [495 rows x 5 columns]

# %% [markdown]
# # Poblacion - 2020 - 2050

# %%
df_2020_2050 = pd.read_csv('../Data/Poblacion_Departamento_2020_2050.csv')

# %%
df_2020_2050 = df_2020_2050[df_2020_2050['ÁREA GEOGRÁFICA'] == 'Total']

# %%
df_2020_2050.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1023 entries, 2 to 2078
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DP               1023 non-null   int64
#  1   DPNOM            1023 non-null   object
#  2   AÑO              1023 non-null   int64
#  3   ÁREA GEOGRÁFICA  1023 non-null   object
#  4   Población        1023 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 48.0+ KB

# %%
df_2020_2050
# Out:
#       DP      DPNOM   AÑO ÁREA GEOGRÁFICA  Población
# 2      5  Antioquia  2020           Total    6649401
# 5      5  Antioquia  2021           Total    6726219
# 8      5  Antioquia  2022           Total    6787846
# 11     5  Antioquia  2023           Total    6848360
# 14     5  Antioquia  2024           Total    6903721
# ...   ..        ...   ...             ...        ...
# 2074  99    Vichada  2046           Total     155150
# 2075  99    Vichada  2047           Total     155867
# 2076  99    Vichada  2048           Total     156528
# 2077  99    Vichada  2049           Total     157136
# 2078  99    Vichada  2050           Total     157691
#
# [1023 rows x 5 columns]

# %% [markdown]
# # Poblaciones Merge

# %%
df_poblacion = pd.concat([df_1993_2004, df_2005_2019, df_2020_2050], ignore_index=True)

# %%
df_poblacion
# Out:
#       DP      DPNOM   AÑO ÁREA GEOGRÁFICA  Población
# 0      5  Antioquia  1993           Total    4607874
# 1      5  Antioquia  1994           Total    4679652
# 2      5  Antioquia  1995           Total    4753428
# 3      5  Antioquia  1996           Total    4828617
# 4      5  Antioquia  1997           Total    4904267
# ...   ..        ...   ...             ...        ...
# 1909  99    Vichada  2046           Total     155150
# 1910  99    Vichada  2047           Total     155867
# 1911  99    Vichada  2048           Total     156528
# 1912  99    Vichada  2049           Total     157136
# 1913  99    Vichada  2050           Total     157691
#
# [1914 rows x 5 columns]

# %% [markdown]
# # Capacidad - Poblaciones Merge

# %%
df_capacidad_instalada.head()
# Out:
#    Anio                                       Departamento  \
# 0  2002                                           Amazonas
# 1  2002                                          Antioquia
# 2  2002                                             Arauca
# 3  2002  Archipiélago de San Andrés, Providencia y Sant...
# 4  2002                                          Atlántico
#
#    Camas de hospitalización  Camas de observación  \
# 0                       115                     8
# 1                      2816                   556
# 2                       233                    39
# 3                        69                     2
# 4                       959                   134
#
#    Consultorios de consulta externa  Consultorios en el servicio de urgencias  \
# 0                                16                                        10
# 1                               894                                       170
# ...

# %%
df_1993_2004.head()
# Out:
#    DP      DPNOM   AÑO                    ÁREA GEOGRÁFICA  Población
# 0   5  Antioquia  1993                           Cabecera    3165505
# 1   5  Antioquia  1993  Centros Poblados y Rural Disperso    1442369
# 2   5  Antioquia  1993                              Total    4607874
# 3   5  Antioquia  1994                           Cabecera    3238892
# 4   5  Antioquia  1994  Centros Poblados y Rural Disperso    1440760

# %%
df_merge = pd.merge(df_capacidad_instalada, df_poblacion[['DP', 'AÑO', 'Población']], how='left', left_on=['Codigo', 'Anio'], right_on=['DP', 'AÑO'])

# %%
df_merge = df_merge[['Anio', 'Codigo', 'Departamento', 'Población', 'Camas de hospitalización',
       'Camas de observación', 'Consultorios de consulta externa',
       'Consultorios en el servicio de urgencias', 'Mesas de partos',
       'Número de unidades de odontología', 'Salas de quirófanos']]

# %%
df_merge
# Out:
#      Anio  Codigo                                       Departamento  \
# 0    2002    91.0                                           Amazonas
# 1    2002     5.0                                          Antioquia
# 2    2002    81.0                                             Arauca
# 3    2002    88.0  Archipiélago de San Andrés, Providencia y Sant...
# 4    2002     8.0                                          Atlántico
# ..    ...     ...                                                ...
# 687  2022    70.0                                              Sucre
# 688  2022    73.0                                             Tolima
# 689  2022    76.0                                    Valle del Cauca
# 690  2022    97.0                                             Vaupés
# 691  2022    99.0                                            Vichada
#
#      Población  Camas de hospitalización  Camas de observación  \
# 0      56082.0                       115                     8
# ...

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 11 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Anio                                      692 non-null    int64
#  1   Codigo                                    671 non-null    float64
#  2   Departamento                              692 non-null    object
#  3   Población                                 671 non-null    float64
#  4   Camas de hospitalización                  692 non-null    int64
#  5   Camas de observación                      692 non-null    int64
#  6   Consultorios de consulta externa          692 non-null    int64
#  7   Consultorios en el servicio de urgencias  692 non-null    int64
#  8   Mesas de partos                           692 non-null    int64
#  9   Número de unidades de odontología         692 non-null    int64
# ...

# %%
df_merge.to_csv('./Data/Capacidad_Instalada_Poblacion.csv', encoding='utf-8-sig', index=False)

# %%
df_merge[df_merge['Anio'] == 2022]['Población'].sum()
# Out:
# 51627601.0

# %%
for index, row in df_merge.iterrows():
    if row['Departamento'] == 'Nacional':
        anio = row['Anio']
        poblacion_nacional = df_merge[df_merge['Anio'] == anio]['Población'].sum()
        df_merge.at[index, 'Población'] = poblacion_nacional
        print(poblacion_nacional)
# Out:
# 40190679.0
# 40693254.0
# 41188093.0
# 41671878.0
# 42170126.0
# 42596590.0
# 43072046.0
# 43511221.0
# 43987712.0
# 44491705.0
# 44939938.0
# 45373399.0
# 45804547.0
# 46252492.0
# 46621373.0
# 47311641.0
# 48149100.0
# 49283723.0
# 50345749.0
# 51117378.0
# 51627601.0

# %%
df_merge
# Out:
#      Anio  Codigo                                       Departamento  \
# 0    2002    91.0                                           Amazonas
# 1    2002     5.0                                          Antioquia
# 2    2002    81.0                                             Arauca
# 3    2002    88.0  Archipiélago de San Andrés, Providencia y Sant...
# 4    2002     8.0                                          Atlántico
# ..    ...     ...                                                ...
# 687  2022    70.0                                              Sucre
# 688  2022    73.0                                             Tolima
# 689  2022    76.0                                    Valle del Cauca
# 690  2022    97.0                                             Vaupés
# 691  2022    99.0                                            Vichada
#
#      Población  Camas de hospitalización  Camas de observación  \
# 0      56082.0                       115                     8
# ...

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 11 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Anio                                      692 non-null    int64
#  1   Codigo                                    671 non-null    float64
#  2   Departamento                              692 non-null    object
#  3   Población                                 692 non-null    float64
#  4   Camas de hospitalización                  692 non-null    int64
#  5   Camas de observación                      692 non-null    int64
#  6   Consultorios de consulta externa          692 non-null    int64
#  7   Consultorios en el servicio de urgencias  692 non-null    int64
#  8   Mesas de partos                           692 non-null    int64
#  9   Número de unidades de odontología         692 non-null    int64
# ...

# %%
df_merge.to_csv('./Data/Capacidad_Instalada_Poblacion.csv', encoding='utf-8-sig', index=False)
