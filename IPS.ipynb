# %%
import pandas as pd

# %%
df = pd.read_csv("./Data/IPS_Atencion_Capacidad.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41427 entries, 0 to 41426
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Departamento                      41427 non-null  object
#  1   Municipio                         41427 non-null  object
#  2   Código prestador                  41427 non-null  int64
#  3   Nombre prestador                  41427 non-null  object
#  4   nit IPS                           41427 non-null  int64
#  5   num digito_verificion             41399 non-null  float64
#  6   naturaleza                        41427 non-null  object
#  7   num nivel atencion                16161 non-null  float64
#  8   Código sede                       41427 non-null  int64
#  9   Número sede                       41427 non-null  int64
#  10  nom sede IPS                      41427 non-null  object
# ...

# %%
df.head()
# Out:
#   Departamento   Municipio  Código prestador  \
# 0     Amazonas  EL ENCANTO        9100100019
# 1     Amazonas  EL ENCANTO        9100100019
# 2     Amazonas  EL ENCANTO        9100100019
# 3     Amazonas  EL ENCANTO        9100100019
# 4     Amazonas  EL ENCANTO        9100100019
#
#                         Nombre prestador   nit IPS   num digito_verificion  \
# 0  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 1  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 2  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 3  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 4  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
#
#   naturaleza  num nivel atencion  Código sede  Número sede  \
# 0    Pública                 2.0   9126300019           11
# 1    Pública                 2.0   9126300019           11
# ...

# %%
df.Departamento.unique()
# Out:
# array(['Amazonas', 'Antioquia', 'Arauca', 'Atlántico', 'Barranquilla',
#        'Bogotá D.C', 'Bolívar', 'Boyacá', 'Buenaventura', 'Caldas',
#        'Cali', 'Caquetá', 'Cartagena', 'Casanare', 'Cauca', 'Cesar',
#        'Chocó', 'Córdoba', 'Cundinamarca', 'Guainía', 'Guaviare', 'Huila',
#        'La Guajira', 'Magdalena', 'Meta', 'Nariño', 'Norte de Santander',
#        'Putumayo', 'Quindío', 'Risaralda', 'San Andrés y Providencia',
#        'Santa Marta', 'Santander', 'Sucre', 'Tolima', 'Valle del cauca',
#        'Vaupés', 'Vichada'], dtype=object)

# %%
len(df.Departamento.unique())
# Out:
# 38

# %%
df.Municipio.unique()
# Out:
# array(['EL ENCANTO', 'LA CHORRERA', 'LA PEDRERA', ..., 'LA PRIMAVERA',
#        'PUERTO CARREÑO', 'SANTA ROSALÍA'], dtype=object)

# %%
len(df.Municipio.unique())
# Out:
# 1027

# %%
Barranquilla
Buenaventura
Cali
Cartagena
Santa Marta
# Out:
#   Input In [10]
#     Santa Marta
#           ^
# SyntaxError: invalid syntax

# %%
df.naturaleza.unique()
# Out:
# array(['Pública', 'Privada', 'Mixta'], dtype=object)

# %%
df[df["Municipio"] == "EL ENCANTO"]
# Out:
#    Departamento   Municipio  Código prestador  \
# 0      Amazonas  EL ENCANTO        9100100019
# 1      Amazonas  EL ENCANTO        9100100019
# 2      Amazonas  EL ENCANTO        9100100019
# 3      Amazonas  EL ENCANTO        9100100019
# 4      Amazonas  EL ENCANTO        9100100019
# 5      Amazonas  EL ENCANTO        9100100019
# 6      Amazonas  EL ENCANTO        9100100019
# 7      Amazonas  EL ENCANTO        9100100019
# 8      Amazonas  EL ENCANTO        9100100019
# 9      Amazonas  EL ENCANTO        9100100019
# 10     Amazonas  EL ENCANTO        9100100019
#
#                          Nombre prestador   nit IPS   num digito_verificion  \
# 0   E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 1   E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 2   E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 3   E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# ...

# %%
df[df["Municipio"] == "LA CHORRERA"]
# Out:
#    Departamento    Municipio  Código prestador  \
# 11     Amazonas  LA CHORRERA        9100100019
# 12     Amazonas  LA CHORRERA        9100100019
# 13     Amazonas  LA CHORRERA        9100100019
# 14     Amazonas  LA CHORRERA        9100100019
# 15     Amazonas  LA CHORRERA        9100100019
# 16     Amazonas  LA CHORRERA        9100100019
# 17     Amazonas  LA CHORRERA        9100100019
# 18     Amazonas  LA CHORRERA        9100100019
#
#                          Nombre prestador   nit IPS   num digito_verificion  \
# 11  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 12  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 13  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 14  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 15  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 16  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# ...

# %%
df[df["Departamento"] == "Bogotá D.C"]
# Out:
#       Departamento Municipio  Código prestador  \
# 7219    Bogotá D.C    BOGOTÁ        1100100032
# 7220    Bogotá D.C    BOGOTÁ        1100100130
# 7221    Bogotá D.C    BOGOTÁ        1100100130
# 7222    Bogotá D.C    BOGOTÁ        1100100130
# 7223    Bogotá D.C    BOGOTÁ        1100100130
# ...            ...       ...               ...
# 11861   Bogotá D.C    BOGOTÁ        1100138773
# 11862   Bogotá D.C    BOGOTÁ        1100138773
# 11863   Bogotá D.C    BOGOTÁ        1100138776
# 11864   Bogotá D.C    BOGOTÁ        1100138789
# 11865   Bogotá D.C    BOGOTÁ        1100138846
#
#                                         Nombre prestador   nit IPS   \
# 7219             COOPERATIVA PARA LA SALUD ORAL ORALCOOP  830000001
# 7220                          INVERSIONES DAMA SALUD SAS  830108482
# 7221                          INVERSIONES DAMA SALUD SAS  830108482
# 7222                          INVERSIONES DAMA SALUD SAS  830108482
# ...

# %%
(df[(df['Departamento'] == 'Bogotá D.C') & (df['nom descripcion capacidad '] == 'Consulta Externa')]).columns
# Out:
# Index(['Departamento', 'Municipio', 'Código prestador', 'Nombre prestador',
#        'nit IPS ', 'num digito_verificion', 'naturaleza', 'num nivel atencion',
#        'Código sede', 'Número sede', 'nom sede IPS', 'Gerente', 'Dirección',
#        'Email', 'Teléfono', 'nom grupo capacidad ',
#        'nom descripcion capacidad ', 'num cantidad capacidad instalada',
#        'Fecha Corte', 'Fuente'],
#       dtype='object')

# %%
(df[(df['Departamento'] == 'Bogotá D.C') & (df['nom descripcion capacidad '] == 'Consulta Externa')])['nom grupo capacidad '].unique()
# Out:
# array(['CONSULTORIOS'], dtype=object)

# %%
(df[(df['Departamento'] == 'Bogotá D.C') & (df['nom descripcion capacidad '] == 'Consulta Externa')]).groupby('num nivel atencion').agg(a = ('num cantidad capacidad instalada', 'sum'))
# Out:
#                        a
# num nivel atencion
# 3.0                 1197

# %%
(df[(df['Departamento'] == 'Antioquia') & (df['nom descripcion capacidad '] == 'Consulta Externa')]).groupby('num nivel atencion').agg(sum = ('num cantidad capacidad instalada', 'sum'))
# Out:
#                     sum
# num nivel atencion
# 1.0                 834
# 2.0                 684
# 3.0                  52
