# %%
import pandas as pd

# %%
df_contratos = pd.read_csv("./Data/SECOP_II_Contratos_Electronicos.csv")

# %%
df_ips = pd.read_csv("./Data/IPS_Atencion_Capacidad.csv")

# %%
df_contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373920 entries, 0 to 373919
# Data columns (total 71 columns):
#  #   Column                                                              Non-Null Count   Dtype
# ---  ------                                                              --------------   -----
#  0   Nombre Entidad                                                      373920 non-null  object
#  1   Nit Entidad                                                         373920 non-null  int64
#  2   Departamento                                                        373920 non-null  object
#  3   Ciudad                                                              373920 non-null  object
#  4   Localización                                                        373920 non-null  object
#  5   Orden                                                               373920 non-null  object
# ...

# %%
df_ips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41427 entries, 0 to 41426
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Departamento                      41427 non-null  object
#  1   Municipio                         41427 non-null  object
#  2   Código prestador                  41427 non-null  int64
#  3   Nombre prestador                  41427 non-null  object
#  4   nit IPS                           41427 non-null  int64
#  5   num digito_verificion             41399 non-null  float64
#  6   naturaleza                        41427 non-null  object
#  7   num nivel atencion                16161 non-null  float64
#  8   Código sede                       41427 non-null  int64
#  9   Número sede                       41427 non-null  int64
#  10  nom sede IPS                      41427 non-null  object
# ...

# %%
df_contratos.columns
# Out:
# Index(['Nombre Entidad', 'Nit Entidad', 'Departamento', 'Ciudad',
#        'Localización', 'Orden', 'Sector', 'Rama', 'Entidad Centralizada',
#        'Proceso de Compra', 'ID Contrato', 'Referencia del Contrato',
#        'Estado Contrato', 'Codigo de Categoria Principal',
#        'Descripcion del Proceso', 'Tipo de Contrato',
#        'Modalidad de Contratacion', 'Justificacion Modalidad de Contratacion',
#        'Fecha de Firma', 'Fecha de Inicio del Contrato',
#        'Fecha de Fin del Contrato', 'Fecha de Inicio de Ejecucion',
#        'Fecha de Fin de Ejecucion', 'Condiciones de Entrega',
#        'TipoDocProveedor', 'Documento Proveedor', 'Proveedor Adjudicado',
#        'Es Grupo', 'Es Pyme', 'Habilita Pago Adelantado', 'Liquidación',
#        'Obligación Ambiental', 'Obligaciones Postconsumo', 'Reversion',
#        'Valor del Contrato', 'Valor de pago adelantado', 'Valor Facturado',
#        'Valor Pendiente de Pago', 'Valor Pagado', 'Valor Amortizado',
# ...

# %%
df_contratos['Fecha de Fin de Ejecucion'].sort_values()
# Out:
# 26039     01/01/2018
# 1403      01/01/2019
# 248292    01/01/2019
# 218398    01/01/2019
# 175001    01/01/2019
#              ...
# 373912           NaN
# 373913           NaN
# 373916           NaN
# 373917           NaN
# 373918           NaN
# Name: Fecha de Fin de Ejecucion, Length: 373920, dtype: object

# %%
df_contratos['Fecha de Inicio del Contrato'].sort_values()
# Out:
# 126975    01/01/2018
# 314220    01/01/2018
# 80879     01/01/2018
# 58810     01/01/2018
# 135330    01/01/2018
#              ...
# 373841           NaN
# 373851           NaN
# 373859           NaN
# 373861           NaN
# 373881           NaN
# Name: Fecha de Inicio del Contrato, Length: 373920, dtype: object

# %%
df_contratos['Fecha de Fin del Contrato'].sort_values()
# Out:
# 248292    01/01/2019
# 218398    01/01/2019
# 204561    01/01/2019
# 149111    01/01/2019
# 271920    01/01/2019
#              ...
# 373489           NaN
# 373521           NaN
# 373608           NaN
# 373678           NaN
# 373859           NaN
# Name: Fecha de Fin del Contrato, Length: 373920, dtype: object

# %%
df_contratos.head()
# Out:
#                                       Nombre Entidad  Nit Entidad  \
# 0  SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...    900959048
# 1                          ESE HOSPITAL SAN BERNARDO    890802223
# 2  SUBRED INTEGRADA DE SERVICIO DE SALUD CENTRO O...    900959051
# 3  SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...    900959048
# 4  SUBRED INTEGRADA DE SERVICIO DE SALUD CENTRO O...    900959051
#
#                  Departamento       Ciudad                     Localización  \
# 0  Distrito Capital de Bogotá  No Definido         Colombia, Bogotá, Bogotá
# 1                      Caldas   Filadelfia  Colombia,  Caldas ,  Filadelfia
# 2  Distrito Capital de Bogotá  No Definido         Colombia, Bogotá, Bogotá
# 3  Distrito Capital de Bogotá  No Definido         Colombia, Bogotá, Bogotá
# 4  Distrito Capital de Bogotá  No Definido         Colombia, Bogotá, Bogotá
#
#          Orden                     Sector                  Rama  \
# ...

# %%
df_contratos = df_contratos[['Nombre Entidad', 'Nit Entidad']]

# %%
df_contratos.head()
# Out:
#                                       Nombre Entidad  Nit Entidad
# 0  SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...    900959048
# 1                          ESE HOSPITAL SAN BERNARDO    890802223
# 2  SUBRED INTEGRADA DE SERVICIO DE SALUD CENTRO O...    900959051
# 3  SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...    900959048
# 4  SUBRED INTEGRADA DE SERVICIO DE SALUD CENTRO O...    900959051

# %%
df_contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373920 entries, 0 to 373919
# Data columns (total 2 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Nombre Entidad  373920 non-null  object
#  1   Nit Entidad     373920 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 5.7+ MB

# %%
df_ips.columns
# Out:
# Index(['Departamento', 'Municipio', 'Código prestador', 'Nombre prestador',
#        'nit IPS ', 'num digito_verificion', 'naturaleza', 'num nivel atencion',
#        'Código sede', 'Número sede', 'nom sede IPS', 'Gerente', 'Dirección',
#        'Email', 'Teléfono', 'nom grupo capacidad ',
#        'nom descripcion capacidad ', 'num cantidad capacidad instalada',
#        'Fecha Corte', 'Fuente'],
#       dtype='object')

# %%
df_ips.head()
# Out:
#   Departamento   Municipio  Código prestador  \
# 0     Amazonas  EL ENCANTO        9100100019
# 1     Amazonas  EL ENCANTO        9100100019
# 2     Amazonas  EL ENCANTO        9100100019
# 3     Amazonas  EL ENCANTO        9100100019
# 4     Amazonas  EL ENCANTO        9100100019
#
#                         Nombre prestador   nit IPS   num digito_verificion  \
# 0  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 1  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 2  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 3  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
# 4  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096                    7.0
#
#   naturaleza  num nivel atencion  Código sede  Número sede  \
# 0    Pública                 2.0   9126300019           11
# 1    Pública                 2.0   9126300019           11
# ...

# %%
df_ips['Fecha Corte']
# Out:
# 0        Fecha corte REPS: Nov  5 2022  1:37PM
# 1        Fecha corte REPS: Nov  5 2022  1:37PM
# 2        Fecha corte REPS: Nov  5 2022  1:37PM
# 3        Fecha corte REPS: Nov  5 2022  1:37PM
# 4        Fecha corte REPS: Nov  5 2022  1:37PM
#                          ...
# 41422    Fecha corte REPS: Nov  5 2022  1:37PM
# 41423    Fecha corte REPS: Nov  5 2022  1:37PM
# 41424    Fecha corte REPS: Nov  5 2022  1:37PM
# 41425    Fecha corte REPS: Nov  5 2022  1:37PM
# 41426    Fecha corte REPS: Nov  5 2022  1:37PM
# Name: Fecha Corte, Length: 41427, dtype: object

# %%
df_ips = df_ips[['Nombre prestador', 'nit IPS ']]

# %%
df_ips.head()
# Out:
#                         Nombre prestador   nit IPS
# 0  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096
# 1  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096
# 2  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096
# 3  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096
# 4  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA  838000096

# %%
df_join = pd.merge(df_contratos, df_ips, how="inner", left_on="Nit Entidad", right_on="nit IPS ")

# %%
df_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21240800 entries, 0 to 21240799
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Nombre Entidad    object
#  1   Nit Entidad       int64
#  2   Nombre prestador  object
#  3   nit IPS           int64
# dtypes: int64(2), object(2)
# memory usage: 810.3+ MB

# %%
df_join
# Out:
#                                              Nombre Entidad  Nit Entidad  \
# 0         SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...    900959048
# 1         SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...    900959048
# 2         SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...    900959048
# 3         SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...    900959048
# 4         SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR OCC...    900959048
# ...                                                     ...          ...
# 21240795              ESE HOSPITAL OSCAR EMIRO VERGARA CRUZ    890985660
# 21240796  EMPRESA SOCIAL DEL ESTADO CENTRO DE SALUD DE C...    820003580
# 21240797  EMPRESA SOCIAL DEL ESTADO CENTRO DE SALUD DE C...    820003580
# 21240798  EMPRESA SOCIAL DEL ESTADO CENTRO DE SALUD DE C...    820003580
# 21240799  EMPRESA SOCIAL DEL ESTADO CENTRO DE SALUD DE C...    820003580
#
#                                            Nombre prestador   nit IPS
# ...

# %%
df_join['Nit Entidad'].unique()
# Out:
# array([900959048, 890802223, 900959051, 900971006, 890500810, 890501438,
#        814003182, 890701033, 808003500, 900196366, 891180268, 807008827,
#        806001061, 819003618, 891780185, 812001579, 860020094, 890304155,
#        806006537, 890905166, 800084206, 802003081, 822006595, 812003996,
#        890701300, 890706833, 891900481, 890303448, 890202024, 800058016,
#        892280033, 900145581, 805027337, 842000004, 890982140, 890680031,
#        800116719, 819003599, 832009187, 890982116, 800163519, 890980765,
#        802013023, 812001219, 891501676, 900109862, 809003590, 832001411,
#        890802218, 892000264, 807008857, 900750333, 900058218, 819001712,
#        900036553, 822002459, 860015929, 818001019, 804013885, 802006267,
#        824000204, 890680025, 899999147, 891800395, 809005452, 814006732,
#        890702476, 802010301, 824000450, 890700666, 802010401, 891301121,
#        891380103, 890103002, 829001887, 890981536, 891800857, 890706823,
# ...

# %%
len(df_join['Nit Entidad'].unique())
# Out:
# 390

# %%
len(df_ips['nit IPS '].unique())
# Out:
# 7915

# %%
len(df_contratos['Nit Entidad'].unique())
# Out:
# 479

# %%
390 / 479, 390 / 7915
# Out:
# (0.81419624217119, 0.049273531269740996)
