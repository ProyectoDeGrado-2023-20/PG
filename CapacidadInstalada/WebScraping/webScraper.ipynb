# %%
# ----------------------------------------------------------------------------
# Libraries Required
# ----------------------------------------------------------------------------

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd

# %%
# ----------------------------------------------------------------------------
# Connect to Website
# ----------------------------------------------------------------------------

# Original URL to connect
siho_url = "https://prestadores.minsalud.gov.co/SIHO/"

# Config of the browser and the driver
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')

# Instatiating the driver
driver = webdriver.Chrome(options)
driver.get(siho_url)


# ----------------------------------------------------------------------------
# Enter the Frame
# ----------------------------------------------------------------------------

# Find all frame HTML tags
frame_elements = driver.find_elements(By.TAG_NAME, "frame")

# Enter the frame
driver.switch_to.frame(frame_elements[1])

# Find and click the button to Log In
login_button = driver.find_element(By.ID, "btnIngresar")
login_button.click()

# Check if there is only one browser window
assert len(driver.window_handles) == 1

# Find and click the link to the element we need
link_new_tab = driver.find_element(By.LINK_TEXT, "Capacidad Instalada")
link_new_tab.click()


# ----------------------------------------------------------------------------
# Enter the New Tab
# ----------------------------------------------------------------------------

# Check if there is a new browser window
assert len(driver.window_handles) == 2

# Get out of the frame and get into the original website
driver.switch_to.default_content()

# Switch to the other window
driver.switch_to.window(driver.window_handles[1])

# Get the list of years to select
search_select_years = driver.find_element(By.ID, "_ctl0_ContentPlaceHolder1_ddano")
select_years = Select(search_select_years)
options_select_years = select_years.options
years = [option.get_attribute("value") for option in options_select_years]

# Get the list of departments to select
search_select_departments = driver.find_element(By.ID, "_ctl0_ContentPlaceHolder1_dddepa_codigo")
select_departments = Select(search_select_departments)
options_select_departments = select_departments.options
departments = [option.text for option in options_select_departments]


# ----------------------------------------------------------------------------
# Functions
# ----------------------------------------------------------------------------

def setSelectedYear(year: str, select_years: Select)->Select:
    """
    Change the year to search, must be in the years list
    """
    select_years.select_by_value(year)    
    
    return select_years

    
def getSelectedYear(select_years: Select)->str:
    """
    Get the year currently selected
    """
    selected_year = select_years.all_selected_options[0].get_attribute("value")

    return selected_year

    
def setSelectedDepartment(department: str, select_departments: Select)->Select:
    """
    Change the departments to search, must be in the departments list
    """
    if department == "Nacional":
        department = ""
    select_departments.select_by_visible_text(department)
    
    return select_departments

    
def getSelectedDepartment(select_departments: Select)->str:
    """
    Get the Department currently selected
    """
    selected_department = select_departments.all_selected_options[0].text
    if selected_department == "":
        selected_department = "Nacional"

    return selected_department

    
def searchData(select_departments: Select)->None:
    """
    Click the Search Button
    """
    selected_department = getSelectedDepartment(select_departments)
    
    search_button = driver.find_element(By.ID, "_ctl0_ibBuscarFtr")
    search_button.click()
    
    wait = WebDriverWait(driver, 10)

    def is_condition_met(driver):
        try:
            span_element = driver.find_element(By.ID, "_ctl0_ContentPlaceHolder1_lblConsulta")
            return span_element.text == selected_department.upper()
        except:
            return False

    wait.until(is_condition_met)


def saveData(select_departments: Select, select_years: Select)->pd.DataFrame:
    """
    Save the data from the webpage to a DataFrame
    """
    df = pd.read_html(driver.page_source, attrs={"id": "_ctl0_ContentPlaceHolder1_dgInforme1"})[0]
    
    new_header = df.iloc[0]
    df = df[1:]
    df.columns = new_header
    df['Departamento'] = getSelectedDepartment(select_departments)
    df['Anio'] = getSelectedYear(select_years)
    df = df[['Departamento', 'Anio', 'Concepto', 'Cantidad']]

    return df


def concatenateDataframes(df1: pd.DataFrame, df2: pd.DataFrame)->pd.DataFrame:
    """
    Concatenate two dataframes with the same columns
    """
    concatenated_df = pd.concat([df1, df2], ignore_index=True)
    
    return concatenated_df
    

def getInstalledCapacity(df1: pd.DataFrame, year: str, department: str, select_years: Select, select_departments: Select)->pd.DataFrame:
    select_years = setSelectedYear(year, select_years)
    select_departments = setSelectedDepartment(department, select_departments)
    searchData(select_departments)
    df2 = saveData(select_departments, select_years)
    df = concatenateDataframes(df1, df2)
    
    return df, select_years, select_departments


# ----------------------------------------------------------------------------
# Initialize the df
# ----------------------------------------------------------------------------

df_all = pd.DataFrame(columns=['Departamento', 'Anio', 'Concepto', 'Cantidad'])

# %%
# ----------------------------------------------------------------------------
# Iterate over years and departments
# ----------------------------------------------------------------------------

for year in years:
    print(year)
    for department in departments:
        print(department)
        
        search_select_years = driver.find_element(By.ID, "_ctl0_ContentPlaceHolder1_ddano")
        select_years = Select(search_select_years)
        
        search_select_departments = driver.find_element(By.ID, "_ctl0_ContentPlaceHolder1_dddepa_codigo")
        select_departments = Select(search_select_departments)
        
        
        # Set Selected Year
        select_years.select_by_value(year)
        
        
        # Set Selected Department
        select_departments.select_by_visible_text(department)
        
        # Search Data
        selected_department = select_departments.all_selected_options[0].text
        if selected_department == "":
            selected_department = "Nacional"
    
        search_button = driver.find_element(By.ID, "_ctl0_ibBuscarFtr")
        search_button.click()
        
        wait = WebDriverWait(driver, 10)

        def is_condition_met(driver):
            try:
                span_element = driver.find_element(By.ID, "_ctl0_ContentPlaceHolder1_lblConsulta")
                return span_element.text == selected_department.upper()
            except:
                return False

        wait.until(is_condition_met)
    
        # Save Data
        df = pd.read_html(driver.page_source, attrs={"id": "_ctl0_ContentPlaceHolder1_dgInforme1"})[0]
        
        new_header = df.iloc[0]
        df = df[1:]
        df.columns = new_header
        df['Departamento'] = selected_department
        df['Anio'] = year
        df = df[['Departamento', 'Anio', 'Concepto', 'Cantidad']]
        
        # Concatenate DataFrames
        df_all = pd.concat([df_all, df], ignore_index=True)
        
        # break
        # print(department, "- Ready")
    # break
# Out:
# 2002
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2003
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2004
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2005
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2006
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2007
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2008
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2009
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2010
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2011
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2012
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2013
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2014
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2015
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2016
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2017
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2018
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2019
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2020
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2021
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# 2022
#
# Amazonas
# Antioquia
# Arauca
# Archipiélago de San Andrés, Providencia y Santa Catalina
# Atlántico
# Barranquilla Distritro Especial
# Bogotá, D.C.
# Bolívar
# Boyacá
# Buenaventura Distrito Especial
# Caldas
# Cali Distrito Especial
# Caquetá
# Cartagena Distrito Especial
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santa Marta Distrito Especial
# Santander
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada

# %%
df_all
# Out:
#      Departamento  Anio                                  Concepto Cantidad
# 0        Nacional  2002                  Camas de hospitalización   25.224
# 1        Nacional  2002                      Camas de observación    4.742
# 2        Nacional  2002          Consultorios de consulta externa    6.131
# 3        Nacional  2002  Consultorios en el servicio de urgencias    1.496
# 4        Nacional  2002                       Salas de quirófanos      810
# ...           ...   ...                                       ...      ...
# 4839      Vichada  2022          Consultorios de consulta externa       24
# 4840      Vichada  2022  Consultorios en el servicio de urgencias        5
# 4841      Vichada  2022                       Salas de quirófanos        2
# 4842      Vichada  2022                           Mesas de partos        5
# 4843      Vichada  2022         Número de unidades de odontología        7
#
# [4844 rows x 4 columns]

# %%
df_all[df_all['Departamento'] == 'Nacional']
# Out:
#      Departamento  Anio                                  Concepto Cantidad
# 0        Nacional  2002                  Camas de hospitalización   25.224
# 1        Nacional  2002                      Camas de observación    4.742
# 2        Nacional  2002          Consultorios de consulta externa    6.131
# 3        Nacional  2002  Consultorios en el servicio de urgencias    1.496
# 4        Nacional  2002                       Salas de quirófanos      810
# ...           ...   ...                                       ...      ...
# 4615     Nacional  2022          Consultorios de consulta externa   13.656
# 4616     Nacional  2022  Consultorios en el servicio de urgencias    7.213
# 4617     Nacional  2022                       Salas de quirófanos      548
# 4618     Nacional  2022                           Mesas de partos    1.072
# 4619     Nacional  2022         Número de unidades de odontología    3.806
#
# [147 rows x 4 columns]

# %%
df_all[df_all['Anio'] == '2022']
# Out:
#      Departamento  Anio                                  Concepto Cantidad
# 4613     Nacional  2022                  Camas de hospitalización   27.083
# 4614     Nacional  2022                      Camas de observación   10.468
# 4615     Nacional  2022          Consultorios de consulta externa   13.656
# 4616     Nacional  2022  Consultorios en el servicio de urgencias    7.213
# 4617     Nacional  2022                       Salas de quirófanos      548
# ...           ...   ...                                       ...      ...
# 4839      Vichada  2022          Consultorios de consulta externa       24
# 4840      Vichada  2022  Consultorios en el servicio de urgencias        5
# 4841      Vichada  2022                       Salas de quirófanos        2
# 4842      Vichada  2022                           Mesas de partos        5
# 4843      Vichada  2022         Número de unidades de odontología        7
#
# [231 rows x 4 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4844 entries, 0 to 4843
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Departamento  4844 non-null   object
#  1   Anio          4844 non-null   object
#  2   Concepto      4844 non-null   object
#  3   Cantidad      4844 non-null   object
# dtypes: object(4)
# memory usage: 151.5+ KB

# %%
df_all.to_csv('./Data/Scraped.csv')

# %%
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------

# ----------------------------------------------------------------------------
# End the Scraper
# ----------------------------------------------------------------------------

driver.quit()
