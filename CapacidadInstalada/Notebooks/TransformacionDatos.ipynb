# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/CapacidadInstaladaRaw.csv", thousands=".")

# %%
df.head()
# Out:
#    Unnamed: 0 Departamento  Anio                                  Concepto  \
# 0           0     Nacional  2002                  Camas de hospitalización
# 1           1     Nacional  2002                      Camas de observación
# 2           2     Nacional  2002          Consultorios de consulta externa
# 3           3     Nacional  2002  Consultorios en el servicio de urgencias
# 4           4     Nacional  2002                       Salas de quirófanos
#
#    Cantidad
# 0     25224
# 1      4742
# 2      6131
# 3      1496
# 4       810

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Departamento  Anio                                  Concepto  Cantidad
# 0     Nacional  2002                  Camas de hospitalización     25224
# 1     Nacional  2002                      Camas de observación      4742
# 2     Nacional  2002          Consultorios de consulta externa      6131
# 3     Nacional  2002  Consultorios en el servicio de urgencias      1496
# 4     Nacional  2002                       Salas de quirófanos       810

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4844 entries, 0 to 4843
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Departamento  4844 non-null   object
#  1   Anio          4844 non-null   int64
#  2   Concepto      4844 non-null   object
#  3   Cantidad      4844 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 151.5+ KB

# %%
df_transformed = df.pivot_table(values="Cantidad", index=["Anio", "Departamento"], columns="Concepto").reset_index()
df_transformed.head()
# Out:
# Concepto  Anio                                       Departamento  \
# 0         2002                                           Amazonas
# 1         2002                                          Antioquia
# 2         2002                                             Arauca
# 3         2002  Archipiélago de San Andrés, Providencia y Sant...
# 4         2002                                          Atlántico
#
# Concepto  Camas de hospitalización  Camas de observación  \
# 0                              115                     8
# 1                             2816                   556
# 2                              233                    39
# 3                               69                     2
# 4                              959                   134
#
# Concepto  Consultorios de consulta externa  \
# 0                                       16
# 1                                      894
# 2                                       33
# 3                                       22
# ...

# %%
df_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Anio                                      692 non-null    int64
#  1   Departamento                              692 non-null    object
#  2   Camas de hospitalización                  692 non-null    int64
#  3   Camas de observación                      692 non-null    int64
#  4   Consultorios de consulta externa          692 non-null    int64
#  5   Consultorios en el servicio de urgencias  692 non-null    int64
#  6   Mesas de partos                           692 non-null    int64
#  7   Número de unidades de odontología         692 non-null    int64
#  8   Salas de quirófanos                       692 non-null    int64
# dtypes: int64(8), object(1)
# memory usage: 48.8+ KB

# %%
df_transformed.to_csv(path_or_buf="../Data/CapacidadInstaladaTransformed.csv", index=False)
